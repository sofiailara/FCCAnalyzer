# %%
import uproot

# %%
f = uproot.open("/home/submit/sofilara/fccee/FCCAnalyzer/tmp/output_xsec_example.root")

# %%
f.keys()
# Out:
# ['p8_ee_Zmumu_ecm91;1',
#  'p8_ee_Zmumu_ecm91/gen_muons_p;1',
#  'p8_ee_Zmumu_ecm91/gen_muons_theta;1',
#  'p8_ee_Zmumu_ecm91/gen_muons_phi;1',
#  'p8_ee_Zmumu_ecm91/gen_muons_no;1',
#  'p8_ee_Zmumu_ecm91/evts_initial;1',
#  'p8_ee_Zmumu_ecm91/leps_all_p;1',
#  'p8_ee_Zmumu_ecm91/leps_all_theta;1',
#  'p8_ee_Zmumu_ecm91/leps_all_phi;1',
#  'p8_ee_Zmumu_ecm91/leps_all_q;1',
#  'p8_ee_Zmumu_ecm91/leps_all_no;1',
#  'p8_ee_Zmumu_ecm91/m_inv;1',
#  'p8_ee_Zmumu_ecm91/emiss;1',
#  'p8_ee_Zmumu_ecm91/visibleEnergy;1',
#  'p8_ee_Zmumu_ecm91/theta_plus;1',
#  'p8_ee_Zmumu_ecm91/theta_minus;1',
#  'p8_ee_Zmumu_ecm91/cos_theta_plus;1',
#  'p8_ee_Zmumu_ecm91/cos_theta_minus;1',
#  'p8_ee_Zmumu_ecm91/acolinearity;1',
#  'p8_ee_Zmumu_ecm91/max_p;1',
#  'p8_ee_Zmumu_ecm91/cosThetac;1',
#  'p8_ee_Zmumu_ecm91/evts_final;1',
#  'p8_ee_Zmumu_ecm91/meta;1',
#  'p8_ee_Ztautau_ecm91;1',
#  'p8_ee_Ztautau_ecm91/gen_muons_p;1',
#  'p8_ee_Ztautau_ecm91/gen_muons_theta;1',
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mlp
from scipy.stats import norm
from scipy.optimize import curve_fit
from scipy import stats
import scipy.integrate as integrate
import scipy.special as special
from hist import Hist
import hist
import math

h = f['p8_ee_Zmumu_ecm91/leps_all_p;1']
print(h)

y,x = h.to_numpy()
plt.plot(x[:-1],y, label='FCC-ee Data')
plt.xlim(0,50)
plt.yscale("log")
plt.xlabel("Dimuon Mass [GeV]")
plt.ylabel("Events")
plt.title("Z Peak")
plt.plot([45.56,45.56],[1e-2,1e10], color ='purple',
         linestyle ='dashed', label ='Mass of Z')
plt.legend()
# Out:
# <TH1D (version 3) at 0x7f05e3cbc7d0>

# %%
h = f['p8_ee_Zmumu_ecm91/leps_all_q']
print(h)

y,x = h.to_numpy()

plt.plot(x[:-1],y, color= 'darkmagenta', label='FCC-ee Data', linestyle = 'dashed')
plt.xlim(-2.5,2.5)
plt.yscale("log")
plt.legend()
# Out:
# <TH1D (version 3) at 0x7f05e084dc90>

# %%
h = f['p8_ee_Zmumu_ecm91/leps_all_no;1']
print(h)

y,x = h.to_numpy()

plt.plot(x[:-1],y, color= 'darkmagenta', label='FCC-ee Data', linestyle = 'dashed')


plt.legend()
# Out:
# <TH1D (version 3) at 0x7f05e0602dd0>

# %%
h = f['p8_ee_Zmumu_ecm91/leps_all_no;1']
print(h)

y,x = h.to_numpy()

plt.scatter(x[:-1],y, color= 'olivedrab', label='FCC-ee Data')
plt.xlim(0,5)
plt.yscale("log")

plt.legend()
# Out:
# <TH1D (version 3) at 0x7f05e0602dd0>

# %%
h = f['p8_ee_Zmumu_ecm91/leps_all_theta;1']
print(h)

y,x = h.to_numpy()

plt.plot(x[:-1],y, color= 'salmon', label='FCC-ee Data', linestyle = 'dashed')

plt.xlim(0,3.1)
plt.legend()
# Out:
# <TH1D (version 3) at 0x7f05d76c6090>

# %%
h = f['p8_ee_Zmumu_ecm91/leps_all_phi']
print(h)

y,x = h.to_numpy()

plt.plot(x[:-1],y, color= 'crimson', label='FCC-ee Data')


plt.legend()
# Out:
# <TH1D (version 3) at 0x7f05d8130d10>

# %%
f = uproot.open("/home/submit/sofilara/fccee/FCCAnalyzer/tmp/output_xsec_example.root")  
h = f['p8_ee_Zmumu_ecm91/leps_all_no;1']
print(h)

y,x = h.to_numpy()

plt.plot(x[:-1],y, color= 'peachpuff', drawstyle='steps-mid')
plt.xlim(0,5)
plt.yscale("log")
# Out:
# <TH1D (version 3) at 0x7f05d8030fd0>

# %%
f = uproot.open("/home/submit/sofilara/fccee/FCCAnalyzer/tmp/output_xsec_example.root")  
h = f['p8_ee_Zmumu_ecm91/m_inv;1']
print(h)

y1,x = h.to_numpy()

plt.plot(x[:-1],y1, color= 'slateblue', drawstyle='steps-mid', label='mumu')
plt.xlim(0,100)
plt.yscale("log")
plt.legend()
integral_mumu = sum(y1)
print(integral_mumu)
# Out:
# <TH1D (version 3) at 0x7f05d7e1e990>
# 9055224.0

# %%
f = uproot.open("/home/submit/sofilara/fccee/FCCAnalyzer/tmp/output_xsec_example.root")  
h = f['p8_ee_Ztautau_ecm91/m_inv;1']
print(h)

y2,x = h.to_numpy()
integral_tautau = sum(y2)
plt.plot(x[:-1],y2, color= 'crimson', drawstyle = 'steps-mid', label='tautau')
plt.xlim(0,100)
plt.yscale("log")
plt.legend()
print(integral_tautau)
# Out:
# <TH1D (version 3) at 0x7f05d756b850>
# 83594.0

# %%
plt.plot(x[:-1], y1, color= 'mistyrose', label='mumu', drawstyle="steps-mid")
plt.plot(x[:-1], y2, color= 'paleturquoise', label='tautau', drawstyle="steps-mid")
plt.yscale("log")
plt.xlim(0,100)
plt.ylim(0,10e5)
plt.legend()
plt.plot([51.5,51.5],[1e-2,1e9], color ='purple', linestyle ='dashed')

plt.title("invariant mass")
plt.ylabel("events")
plt.xlabel("invariant mass")
plt.rcParams['font.family']=['serif']
# Out:
# /tmp/ipykernel_861782/2705354768.py:5: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(0,10e5)

# %%
plt.plot(x[:-1], y1*1462.08*103/10000000, color = 'lavender', label='mumu', drawstyle="steps-mid")
plt.plot(x[:-1], y2*1476.58*103/10000000, label ='tautau', drawstyle="steps-mid",color= 'lightcyan')
plt.yscale("log")
plt.xlim(0,100)
plt.title("normalization")
ax=plt.gca()
ax.set_facecolor('lightslategrey')
plt.legend()

# %%
integral_total= integral_mumu + integral_tautau
print(integral_total)
# Out:
# 9138818.0

# %%
f = uproot.open("/home/submit/sofilara/fccee/FCCAnalyzer/tmp/output_xsec_example.root")  
h = f['p8_ee_Zmumu_ecm91/emiss;1']
print(h)

y3,x = h.to_numpy()

plt.plot(x[:-1],y3, color= 'slateblue', drawstyle='steps-mid', label='mumu')
#plt.xlim(0,100)
plt.yscale("log")
plt.legend()
integral_mumu = sum(y1)
print(integral_mumu)
# Out:
# <TH1D (version 3) at 0x7f05d74a9d50>
# 9055224.0

# %%
f = uproot.open("/home/submit/sofilara/fccee/FCCAnalyzer/tmp/output_xsec_example.root")  
h = f['p8_ee_Ztautau_ecm91/emiss;1']
print(h)

y4,x = h.to_numpy()
integral_tautau = sum(y2)
plt.plot(x[:-1],y4, color= 'crimson', drawstyle = 'steps-mid', label='tautau')
#plt.xlim(0,100)
plt.yscale("log")
plt.legend()
print(integral_tautau)
result=y2
# Out:
# <TH1D (version 3) at 0x7f05d71d2710>
# 83594.0

# %%
plt.plot(x[:-1], y3*1462.08*150000000/10000000, color= 'turquoise', label='$µ^+µ^-$', drawstyle="steps-mid")
plt.plot(x[:-1], y4*1462.08*150000000/10000000, color= 'lightslategrey', label='$τ^+τ^-$', drawstyle="steps-mid")
plt.yscale("log")
plt.xlabel("Missing Energy")
plt.ylabel("Events")
plt.xlim(0,40)
plt.legend()
plt.plot([22.25,22.25],[0,1e11], color ='plum',
         linestyle ='dashed')
plt.title("Normalized Missing Energy")
# Out:
# Text(0.5, 1.0, 'Normalized Missing Energy')

# %%
import mplhep as hep 
#h_mumu = f['p8_ee_Zmumu_ecm91/m_inv;1']
#h_tautau = f['p8_ee_Ztautau_ecm91/m_inv;1']
#w1 = 103*1462.08/10000000
#w2 = 103*1476.58/10000000
#hep.histplot([h_mumu*w1,h_tautau*w2], label=[r'$mumu$',r'$tautau$'])
#plt.yscale("log")
#plt.xlim(0,100)
#plt.legend()

# %%
f = uproot.open("/home/submit/sofilara/fccee/FCCAnalyzer/tmp/output_xsec_example.root")  
h = f['p8_ee_Zmumu_ecm91/m_inv;1']
print(h)

y1,x = h.to_numpy()

plt.plot(x[:-1],y1, color= 'slateblue', drawstyle='steps-mid', label='$µ^+µ^-$')
plt.xlim(0,100)
plt.ylim(10e3,10e10)
plt.yscale("log")
plt.legend()
integral_mumu = sum(y1)
print(integral_mumu)

f = uproot.open("/home/submit/sofilara/fccee/FCCAnalyzer/tmp/output_xsec_example.root")  
h = f['p8_ee_Ztautau_ecm91/m_inv;1']
print(h)

y2,x = h.to_numpy()
integral_tautau = sum(y2)
plt.plot(x[:-1],y2, color= 'crimson', drawstyle = 'steps-mid', label='$τ^+τ^-$')
plt.xlim(0,100)
plt.ylim(10e3,10e10)
plt.yscale("log")
plt.legend()
print(integral_tautau)

plt.title("invariant mass")
plt.ylabel("events")
plt.xlabel("invariant mass")

ax=plt.gca()
ax.set_facecolor('mintcream')
plt.rcParams['font.family']=['serif']

#plt.plot(x[:-1], y1*1462.08*103/10000000, color = 'lavender', label='mumu', drawstyle="steps-mid")
#plt.plot(x[:-1], y2*1476.58*103/10000000, label ='tautau', drawstyle="steps-mid",color= 'lightcyan')
#plt.yscale("log")
#plt.xlim(0,100)
#plt.title("normalization")
#ax=plt.gca()
#ax.set_facecolor('lightslategrey')
#plt.legend()           

plt.plot([51.652499999999996,51.652499999999996],[1e-2,1e10], color ='purple',
         linestyle ='dashed')
# Out:
# <TH1D (version 3) at 0x7f05d81ba750>
# 9055224.0
# <TH1D (version 3) at 0x7f05d8115cd0>
# 83594.0

# %%
domain = np.arange(start = 50,stop = 100)
w1 = 1462.08*103/10000000
w2 = 1476.58*103/10000000
#h_mumu = f['p8_ee_Zmumu_ecm91/m_inv;1'].to_hist()
h_mumu = f['p8_ee_Zmumu_ecm91/m_inv;1'].to_hist()*w1
x = h_mumu.axes[0].centers
#h_tautau = f['p8_ee_Ztautau_ecm91/m_inv;1'].to_hist()
h_tautau = f['p8_ee_Ztautau_ecm91/m_inv;1'].to_hist()*w2

domain_values = domain
s_list = []
b_list = []
ratio_list = []

fractions_list = []
for i in x:
    
    integral = h_mumu[i*1.0j:].sum()
    integral2 = h_tautau[i*1.0j:].sum()
    s_list.append(integral)
    b_list.append(integral2)
    ratio = integral.value/(np.sqrt(integral.value+integral2.value))
    ratio_list.append(ratio)
# Out:
# /tmp/ipykernel_861782/701315200.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   ratio = integral.value/(np.sqrt(integral.value+integral2.value))

# %%
plt.plot(x, ratio_list, color = 'mediumslateblue')
max_y = max(ratio_list)
max_x = x[ratio_list.index(max_y)]
print(max_x, max_y)
plt.plot([52.0125,52.0125],[0,400], color = 'slategray',
         linestyle ='dashed', label = "optimized")
plt.legend()
plt.title("Normalized Invariant Mass")
plt.ylabel("Ratio")
plt.xlabel("Invariant Mass")
plt.xlim(35,70)
plt.ylim(369,371)


ax=plt.gca()
ax.set_facecolor('white')
plt.rcParams['font.family']=['serif']
# Out:
# 48.205 367.7591209849915

# %%
f = uproot.open("/home/submit/sofilara/fccee/FCCAnalyzer/tmp/output_xsec_example.root")  
h = f['p8_ee_Zmumu_ecm91/m_inv;1']

y1,x = h.to_numpy()

f = uproot.open("/home/submit/sofilara/fccee/FCCAnalyzer/tmp/output_xsec_example.root")  
p = f['p8_ee_Ztautau_ecm91/m_inv;1']

y2,x = p.to_numpy()



plt.plot(x[:-1], y1*1462.08*150000000/10000000, color = 'mediumslateblue', label='$µ^+µ^-$', drawstyle="steps-mid")
plt.plot(x[:-1], y2*1476.58*150000000/10000000, label ='$τ^+τ^-$', drawstyle="steps-mid",color= 'lightsteelblue')
plt.yscale("log")
plt.xlim(0,100)
plt.ylim(1e4,10e9)
plt.title("Normalized Invariant Mass")
plt.ylabel("Events")
plt.xlabel("Invariant Mass")
plt.legend()

ax=plt.gca()
ax.set_facecolor('white')
plt.rcParams['font.family']=['serif']
           

plt.plot([51.652499999999996,51.652499999999996],[1e4,1e9], color ='plum',
         linestyle ='dashed')

# %%
#NORMALIZE!!!!!!!
f = uproot.open("/home/submit/sofilara/fccee/FCCAnalyzer/tmp/output_xsec_example.root")  
h = f['p8_ee_Zmumu_ecm91/emiss;1']
print(h)

y3,x = h.to_numpy()

plt.plot(x[:-1],y3, color= 'slateblue', drawstyle='steps-mid', label='mumu')
#plt.xlim(0,100)
plt.yscale("log")
plt.legend()
integral_mumu = sum(y1)
print(integral_mumu)

f = uproot.open("/home/submit/sofilara/fccee/FCCAnalyzer/tmp/output_xsec_example.root")  
h = f['p8_ee_Ztautau_ecm91/emiss;1']
print(h)

y4,x = h.to_numpy()
integral_tautau = sum(y2)
plt.plot(x[:-1],y4, color= 'crimson', drawstyle = 'steps-mid', label='tautau')
#plt.xlim(0,100)
plt.yscale("log")
plt.legend()
print(integral_tautau)
result=y2

plt.plot(x[:-1], y3, color= 'mistyrose', label='mumu', drawstyle="steps-mid")
plt.plot(x[:-1], y4, color= 'paleturquoise', label='tautau', drawstyle="steps-mid")
plt.yscale("log")
plt.xlabel("missing energy")
plt.ylabel("events")
plt.xlim(0,90)
plt.legend()
plt.plot([22.25,22.25],[0,1e10], color ='purple',
         linestyle ='dashed')
plt.title("missing energy")
# Out:
# <TH1D (version 3) at 0x7f05d7126190>
# 9055224.0
# <TH1D (version 3) at 0x7f05d6e9d5d0>
# 83594.0
# Text(0.5, 1.0, 'missing energy')

# %%
domain = np.arange(start = 20,stop = 30)
w1 = 1462.08*150000000/10000000
w2 = 1476.58*150000000/10000000
#h_mumu = f['p8_ee_Zmumu_ecm91/m_inv;1'].to_hist()
h_mumu = f['p8_ee_Zmumu_ecm91/emiss;1'].to_hist()*w1
x = h_mumu.axes[0].centers
#h_tautau = f['p8_ee_Ztautau_ecm91/m_inv;1'].to_hist()
h_tautau = f['p8_ee_Ztautau_ecm91/emiss;1'].to_hist()*w2

domain_values = domain
s_list = []
b_list = []
ratio_list = []
x_list = []

fractions_list = []
for index, i in enumerate(x):
    
    if index==0: continue
    
    integral = h_mumu[0.0j:i*1.0j].sum()
    integral2 = h_tautau[0.0j:i*1.0j].sum()
    s_list.append(integral)
    b_list.append(integral2)
    ratio = integral.value/(np.sqrt(integral.value+integral2.value))
    ratio_list.append(ratio)
    x_list.append(i)

# %%
plt.plot(x_list, ratio_list, color = 'turquoise')
max_y = max(ratio_list)
max_x = x[ratio_list.index(max_y)]
print(max_x, max_y)
#plt.plot([52.0125,52.0125],[0,60000], color = 'slategray',
         #linestyle ='dashed', label = "optimized")
#plt.legend()
plt.title("Ratios of Missing Energy")
plt.ylabel("Ratio")
plt.xlabel("Missing Energy")
plt.xlim(10,35)
plt.ylim(306750,308000)

ax=plt.gca()
ax.set_facecolor('white')
plt.rcParams['font.family']=['serif']
plt.plot([22.25,22.25],[150000,350000], color = 'plum',
         linestyle ='dashed', label = "optimized")
# Out:
# 22.25 305119.9926853929

# %%
f = uproot.open("/home/submit/sofilara/fccee/FCCAnalyzer/tmp/output_xsec_example.root")  
h = f['p8_ee_Zmumu_ecm91/weight;1']

y1,x = h.to_numpy()

f = uproot.open("/home/submit/sofilara/fccee/FCCAnalyzer/tmp/output_xsec_example.root")  
p = f['p8_ee_Zmumu_ecm91/weight;2']

y2,x = p.to_numpy()



plt.plot(x[:-1], y1, color = 'mediumslateblue', label='weight1', drawstyle="steps-mid")
plt.plot(x[:-1], y2, label ='weight2', drawstyle="steps-mid",color= 'lightsteelblue')
plt.yscale("log")
#plt.xlim(0,100)
#plt.ylim(1e4,10e9)
plt.title("weight mumu")
#plt.ylabel("Events")
#plt.xlabel("Invariant Mass")
plt.legend()

ax=plt.gca()
ax.set_facecolor('white')
plt.rcParams['font.family']=['serif']
           

#plt.plot([51.652499999999996,51.652499999999996],[1e4,1e9], color ='plum',
         #linestyle ='dashed')
fraction = y2/y1
print(fraction)
# Out:
# ---------------------------------------------------------------------------
# KeyInFileError                            Traceback (most recent call last)
# Cell In[27], line 2
#       1 f = uproot.open("/home/submit/sofilara/fccee/FCCAnalyzer/tmp/output_xsec_example.root")
# ----> 2 h = f['p8_ee_Zmumu_ecm91/weight;1']
#       4 y1,x = h.to_numpy()
#       6 f = uproot.open("/home/submit/sofilara/fccee/FCCAnalyzer/tmp/output_xsec_example.root")
#
# File /work/submit/sofilara/miniforge3/envs/fcc/lib/python3.11/site-packages/uproot/reading.py:2090, in ReadOnlyDirectory.__getitem__(self, where)
#    2088     else:
#    2089         last = step
# -> 2090         step = step[item]
#    2092 elif isinstance(step, uproot.behaviors.TBranch.HasBranches):
#    2093     return step["/".join(items[i:])]
#
# File /work/submit/sofilara/miniforge3/envs/fcc/lib/python3.11/site-packages/uproot/reading.py:2107, in ReadOnlyDirectory.__getitem__(self, where)
#    2104     return step
#    2106 else:
# ...

# %%
f = uproot.open("/home/submit/sofilara/fccee/FCCAnalyzer/tmp/output_xsec_example.root")  
h = f['p8_ee_Ztautau_ecm91/weight;1']

y1,x = h.to_numpy()

f = uproot.open("/home/submit/sofilara/fccee/FCCAnalyzer/tmp/output_xsec_example.root")  
p = f['p8_ee_Ztautau_ecm91/weight;2']

y2,x = p.to_numpy()



plt.plot(x[:-1], y1, color = 'mediumslateblue', label='weight1', drawstyle="steps-mid")
plt.plot(x[:-1], y2, label ='weight2', drawstyle="steps-mid",color= 'lightsteelblue')
plt.yscale("log")
#plt.xlim(0,100)
#plt.ylim(1e4,10e9)
plt.title("weight tautau")
#plt.ylabel("Events")
#plt.xlabel("Invariant Mass")
plt.legend()

ax=plt.gca()
ax.set_facecolor('white')
plt.rcParams['font.family']=['serif']
           

#plt.plot([51.652499999999996,51.652499999999996],[1e4,1e9], color ='plum',
         #linestyle ='dashed')
fraction = y2/y1
print(fraction)

# %%
f = uproot.open("/home/submit/sofilara/fccee/FCCAnalyzer/tmp/output_xsec_example.root")  
h = f['p8_ee_Zmumu_ecm91/m_inv;1']

y1,x = h.to_numpy()

f = uproot.open("/home/submit/sofilara/fccee/FCCAnalyzer/tmp/output_xsec_example.root")  
p = f['p8_ee_Ztautau_ecm91/m_inv;1']

y2,x = p.to_numpy()



plt.plot(x[:-1], y1*1462.08*150000000/10000000, color = 'mediumslateblue', label='$µ^+µ^-$', drawstyle="steps-mid")
plt.plot(x[:-1], y2*1476.58*150000000/10000000, label ='$τ^+τ^-$', drawstyle="steps-mid",color= 'lightsteelblue')
plt.yscale("log")
plt.xlim(0,100)
plt.ylim(1e4,10e9)
plt.title("Normalized Invariant Mass")
plt.ylabel("Events")
plt.xlabel("Invariant Mass")
plt.legend()

ax=plt.gca()
ax.set_facecolor('white')
plt.rcParams['font.family']=['serif']
           

plt.plot([51.652499999999996,51.652499999999996],[1e4,1e9], color ='plum',
         linestyle ='dashed')
